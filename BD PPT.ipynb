# %%
import pandas as pd
import matplotlib as mp
import numpy as np
import statsmodels.api as sm
import sklearn as sk

# %%
cir = pd.read_csv('cirurgias.csv', sep=';')

# %%
cir
# Out:
#                            Nome     Genero   Data Nasc Data Cirurgia  \
# 0              Lourival Crispin  Masculino         NaN    12/06/2002
# 1             Maria Zeli Wagner   Feminino         NaN    19/06/2002
# 2                Elias Oliveira  Masculino         NaN    21/06/2002
# 3            Roseli de Oliveira   Feminino         NaN    26/06/2002
# 4          Lindolfo José Schulz  Masculino         NaN    27/06/2002
# ...                         ...        ...         ...           ...
# 2246     Carlos Alberto Neumann  Masculino  16/03/1963    19/08/2020
# 2247  Osni Geraldo da Conceição  Masculino  27/08/1959    24/08/2020
# 2248     Estela Maria Schweizer   Feminino  25/02/1967    26/08/2020
# 2249      Carmen Luzia da Costa   Feminino  02/06/1948    28/08/2020
# 2250     Sônia Damásio da Silva   Feminino  08/07/1992    04/09/2020
#
#      Cirurgia com CEC Fonte Pagadora Hospital Oxigenador Cardioplegia  \
# ...

# %%
cadastro = [('Renato Bastos Pope', 45, 'München'),('Fábio Bastos Pope', 43, 'Rio de Janeiro'),('Thiago Bastos Pope', 36, 'Rio de Janeiro')]

# %%
 print(cadastro)
# Out:
# [('Renato Bastos Pope', 45, 'München'), ('Fábio Bastos Pope', 43, 'Rio de Janeiro'), ('Thiago Bastos Pope', 36, 'Rio de Janeiro')]
